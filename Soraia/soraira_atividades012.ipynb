# %%
import pandas as pd

# %%
df = pd.read_csv("data_sample_PE.csv", sep = ";")

# %%
#nomes e tipos de cada coluna
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAO TOTAL. HORARIO (mm)                           float64
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)    float64
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          float64
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         float64
# RADIACAO GLOBAL (Kj/m2)                                  float64
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)              float64
# TEMPERATURA DO PONTO DE ORVALHO (C)                      float64
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                float64
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                float64
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)          float64
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)          float64
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# ...

# %%
df.columns #mostra o nome das colunas
# Out:
# Index(['Data', 'Hora UTC', 'PRECIPITAO TOTAL. HORARIO (mm)',
#        'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)',
#        'PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#        'PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
#        'RADIACAO GLOBAL (Kj/m2)',
#        'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)',
#        'TEMPERATURA DO PONTO DE ORVALHO (C)',
#        'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)',
#        'TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)',
#        'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)',
#        'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)',
#        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
#        'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#        'UMIDADE RELATIVA DO AR. HORARIA (%)',
#        'VENTO. DIREAO HORARIA (gr) ((gr))', 'VENTO. RAJADA MAXIMA (m/s)',
#        'VENTO. VELOCIDADE HORARIA (m/s)', 'REGIAO', 'UF', 'ESTACAO',
#        'CODIGO (WMO)', 'LATITUDE', 'LONGITUDE', 'ALTITUDE',
# ...

# %%
#delimitando colunas q vou usar
df[['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)',
    'TEMPERATURA DO PONTO DE ORVALHO (C)',
    'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)',
    'TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)',
    'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)',
    'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)']]

# %%
#aqui tem as médias de todas temperaturas e outra medidas
df[['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)',
    'TEMPERATURA DO PONTO DE ORVALHO (C)',
    'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)',
    'TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)',
    'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)',
    'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)']].describe()
# Out:
#        TEMPERATURA DO AR - BULBO SECO. HORARIA (C)  \
# count                                 54658.000000
# mean                                     25.339705
# std                                       4.337417
# min                                      13.500000
# 25%                                      22.100000
# 50%                                      25.000000
# 75%                                      28.500000
# max                                      39.100000
#
#        TEMPERATURA DO PONTO DE ORVALHO (C)  \
# count                         50855.000000
# mean                             16.998169
# std                               4.748053
# min                              -7.100000
# 25%                              15.700000
# 50%                              17.900000
# 75%                              19.800000
# max                              27.100000
#
#        TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)  \
# count                               54612.000000
# ...

# %%
#Mas vou fazer separado as médias das temperaturas
df[['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)',
    'TEMPERATURA DO PONTO DE ORVALHO (C)',
    'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)',
    'TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)',
    'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)',
    'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)']].mean()
# Out:
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)        25.339705
# TEMPERATURA DO PONTO DE ORVALHO (C)                16.998169
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)          25.972929
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)          24.689669
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)    17.540566
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)    16.484334
# dtype: float64

# %% [markdown]
# BÔNUS

# %%
#selecionar as colunas q eu quero
colunas = df[['VENTO. DIREAO HORARIA (gr) ((gr))', 'VENTO. RAJADA MAXIMA (m/s)',
       'VENTO. VELOCIDADE HORARIA (m/s)']]

#tirar valores nulos
colunas_sem_null = colunas.dropna(subset=['VENTO. DIREAO HORARIA (gr) ((gr))', 'VENTO. RAJADA MAXIMA (m/s)',
       'VENTO. VELOCIDADE HORARIA (m/s)'])

#pegar somente 100 linhas dessas colunas sem valores nulos
colunas_sem_null.sample(100)
# Out:
#        VENTO. DIREAO HORARIA (gr) ((gr))  VENTO. RAJADA MAXIMA (m/s)  \
# 72137                              157.0                         4.5
# 39476                              118.0                         7.6
# 36042                              158.0                         5.2
# 11161                              155.0                         5.9
# 30147                               97.0                         3.0
# ...                                  ...                         ...
# 42184                               73.0                         6.9
# 37131                              276.0                         9.8
# 87185                              154.0                         5.6
# 86600                              157.0                         7.6
# 20548                               93.0                         8.7
#
#        VENTO. VELOCIDADE HORARIA (m/s)
# 72137                              1.0
# 39476                              3.8
# ...
